# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\KATYAYANI\Downloads\imdb_anime.csv")

# %%
data
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
data1=data.copy()

# %%
data1
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
data1.fillna({"Title":"no title","Genre":"no genre","User Rating":0,"Number of Votes":0,"Runtime":"10","Year":0,"Summary":"no summary","Stars":"no stars","Certificate":"no certificate","Metascore":0,"Gross":10,"Episode":0,"Episode Title":"no"},inplace=True)

# %%
data1.replace({"User Rating":{"User Rating":0},"Number of Votes":{"Number of Votes":0},"Runtime":{"Runtime":"10"},"Metascore":{"Metascore":0},"Gross":{"Gross":10},"Episode":{"Episode":0}},inplace=True)

# %%
data1=data1.astype({"User Rating":np.float16,"Metascore":int,"Gross":int,"Episode":int})

# %%
def func(x):
    return x.replace(" min","")
def f(x):
    return int(x)
def f1(x):
    return x.replace(",","")
data1["Runtime"]=data1["Runtime"].map(func).map(f1).map(f)

# %%
def func(x):
    return x.replace(" min","")
def f(x):
    return int(x)
def f1(x):
    return x.replace(",","")
def f2(x):
    return str(x)
data1["Number of Votes"]=data1["Number of Votes"].map(f2).map(func).map(f1).map(f)

# %%
#1.How many unique anime are there?
len(data["Title"].unique())

# By analyzing title column i found that 9851 unique anime are there in the data set.
# Out:
# 9851

# %%
#2.Which anime has the highest rating?
a=data1["User Rating"].max()
b=data1.loc[data1["User Rating"]==a,["Title"]]
print(b) 

# by analyzing the data i got highest rating anime they are: 
#13656                    Idaten Jump
#17874                   Vinland Saga
#22753                Attack on Titan
#34677                Hunter x Hunter
#39614  Legend of the Galactic Heroes
#45689                Attack on Titan
# Out:
#                                Title
# 13656                    Idaten Jump
# 17874                   Vinland Saga
# 22753                Attack on Titan
# 34677                Hunter x Hunter
# 39614  Legend of the Galactic Heroes
# 45689                Attack on Titan

# %%
#3.Which anime has a rating between 7.0 to 9.0?
a=data1.loc[(data1["User Rating"]>=7.0) & (data1["User Rating"]<=9),["Title"]]
a

# by analyzing the data i found that which anime rating is between 7.0 and 9.0.
# Out:
#                                              Title
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 4                                   Jujutsu Kaisen
# 6                   Demon Slayer: Kimetsu no Yaiba
# ...                                            ...
# 45709               Demon Slayer: Kimetsu no Yaiba
# 45710               Demon Slayer: Kimetsu no Yaiba
# 45711               Demon Slayer: Kimetsu no Yaiba
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
#
# [15655 rows x 1 columns]

# %%
#4.Which anime has the lowest runtime?
a=data1["Runtime"].min()
b=data1.loc[data1["Runtime"]==a,["Title"]]
print(b)

#by analyzing the data 
#2809                   Ani*Kuri15
#3588                Henkei Shoujo
#3708   Gloomy the Naughty Grizzly
#4548                      Usavich
#4792                 Tokino Kousa
#...                           ...
#23772  Gloomy the Naughty Grizzly
#23773  Gloomy the Naughty Grizzly
#23774  Gloomy the Naughty Grizzly
#23775  Gloomy the Naughty Grizzly
#33433                  Ani*Kuri15 i find this anime has lowest runtime.
# Out:
#                             Title
# 2809                   Ani*Kuri15
# 3588                Henkei Shoujo
# 3708   Gloomy the Naughty Grizzly
# 4548                      Usavich
# 4792                 Tokino Kousa
# ...                           ...
# 23772  Gloomy the Naughty Grizzly
# 23773  Gloomy the Naughty Grizzly
# 23774  Gloomy the Naughty Grizzly
# 23775  Gloomy the Naughty Grizzly
# 33433                  Ani*Kuri15
#
# [149 rows x 1 columns]

# %%
#4.Which anime has the highest runtime?
a=data1["Runtime"]
b=a.max()
c=data1.loc[a==b,["Title","Runtime"]]
c

# BY analyzing the data i got 2798 The Wonderful Wizard of Oz 1271 had the highest runtime.
# Out:
#                            Title  Runtime
# 2798  The Wonderful Wizard of Oz     1271

# %%
#5.What is the runtime difference between one Piece and the super mario bros movie?
r=data1.loc[data1["Title"]=="One Piece",["Runtime"]].sum()
k=data1.loc[data1["Title"]=="The Super Mario Bros. Movie",["Runtime"]].sum()
print(r-k)

# By analyzing the data i finded that runtime difference between one Piece and the super mario bros movie is 11249.
# Out:
# Runtime    11249
# dtype: int64

# %%
#6.Which is the oldest anime?
#not getting

# %%
#7. List all the anime that were released in the year 2023.
# not getting

# %%
#9.Which anime has the lowest gross price?
a=data1["Gross"].min()
b=data1.loc[data1["Gross"]==a,["Title"]]
print(b)

# By analyzing the data i finded that 
#3233                                          Show Time!
#5620                                   The Peasant Noble
#5714   Meitantei Conan Magic File 4: Osaka okonomiyak...
#6142   Fist of the North Star Legennd of Heroes - Spe...
#6236                                     Shakotan Boogie
#...                                                  ...
#45600                                    Girl Beats Boys
#45601                                    Girl Beats Boys
#45602                                    Girl Beats Boys
#45606                                    Girl Beats Boys
#45608                                    Girl Beats Boys these animes has the lowest gross price.
# Out:
#                                                    Title
# 3233                                          Show Time!
# 5620                                   The Peasant Noble
# 5714   Meitantei Conan Magic File 4: Osaka okonomiyak...
# 6142   Fist of the North Star Legennd of Heroes - Spe...
# 6236                                     Shakotan Boogie
# ...                                                  ...
# 45600                                    Girl Beats Boys
# 45601                                    Girl Beats Boys
# 45602                                    Girl Beats Boys
# 45606                                    Girl Beats Boys
# 45608                                    Girl Beats Boys
#
# [168 rows x 1 columns]

# %%
#10Which anime has the highest gross price?
a=data1["Gross"].max()
b=data1.loc[data1["Gross"]==a,["Title"]]
print(b)

# By analyzing the data i finded that
#47   WALL·E
#888  WALL·E two animes had the highest gross price.
# Out:
#       Title
# 47   WALL·E
# 888  WALL·E

# %%
#11.How many anime have the PG certification?
d=data1.loc[data1["Certificate"]=="PG",["Title"]]
len(d)
d



# By analyzing the cerificate column i finded that 425 animes got pg cerifications.
# Out:
#                                              Title
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 7                     Puss in Boots: The Last Wish
# 11                                        Coraline
# 17                                          Sing 2
# ...                                            ...
# 41231                         You're Under Arrest!
# 41232                         You're Under Arrest!
# 41233                         You're Under Arrest!
# 41234                         You're Under Arrest!
# 41235                         You're Under Arrest!
#
# [425 rows x 1 columns]

# %%
#12.What is the average number of votes in your dataset
data1["Number of Votes"].mean()

# by doing the mean i finded that average number of votes in my data set.
# Out:
# 1632.1920510969662
